# %% [markdown]
# ##Datalab Semester 2

# %%
pip install pandas
pip install sqlite3
pip install matplotlib
pip install seaborn
pip install scikit-learn
# Out:
#   Cell In[1], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax
