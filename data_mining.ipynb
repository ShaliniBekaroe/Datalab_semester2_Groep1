# %%
print("hallowioyufyb ewufcn)

# %%
#tdjdfjydfyjdtjwfqrg3qwgS
#olla7
print('hihihihih')
# Out:
# hihihihih

# %% [markdown]
# gygyugyu

# %%
print('test')
# Out:
# test

# %%
print('test2')

# %% [markdown]
# test 12
